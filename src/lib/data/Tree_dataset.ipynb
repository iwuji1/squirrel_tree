# %%
#Collating Trees Dataset for use
# Out:
# Failed to start the Kernel.
#
# EnvironmentLocationNotFound: Not a conda environment: /"/Users/obiwuji/Desktop/Side Projects/Freelance/3D Trees/3d_trees_london/.conda".
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import numpy as np
# Out:
# Failed to start the Kernel.
#
# EnvironmentLocationNotFound: Not a conda environment: /"/Users/obiwuji/Desktop/Side Projects/Freelance/3D Trees/3d_trees_london/.conda".
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
